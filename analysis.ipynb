# %% [markdown]
# # Evolution algorithms analysis

# %%
import source.visualisation as vis
import source.benchmark_functions as bf

vis.visualize_2d_function(bf.dejong)
vis.visualize_3d_function(bf.dejong)
